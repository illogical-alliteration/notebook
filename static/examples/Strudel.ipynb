// %% [markdown]
// # Strudel
// [Strudel](https://strudel.cc) is a music library for creating music programmatically. This notebook demonstrates how to load the library, create a simple rythm, and stop playback.

// %%
strudel = await import("https://esm.sh/@strudel/web?bundle");
controls = await strudel.initStrudel();

// %%
note("c3 e3 g3 b3").s("sine").play()

// %%
hush()
